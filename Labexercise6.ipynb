# %% [markdown]
# <a href="https://colab.research.google.com/github/Seungzy/Data-Visualization/blob/main/Labexercise6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('properties.csv')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=283, step=1)

# %%
data.columns
# Out:
# Index(['url', 'name', 'price', 'formatted_price', 'currency', 'address',
#        'locality', 'region', 'postal_code', 'country', 'latitude', 'longitude',
#        'description', 'baths', 'beds', 'sqft', 'property_details', 'images',
#        'listed_by', 'uniq_id', 'scraped_at'],
#       dtype='object')

# %%
data.dtypes
# Out:
# url                  object
# name                 object
# price                 int64
# formatted_price      object
# currency             object
# address              object
# locality             object
# region               object
# postal_code          object
# country              object
# latitude            float64
# longitude           float64
# description          object
# baths               float64
# beds                float64
# sqft                float64
# property_details     object
# images               object
# listed_by            object
# uniq_id              object
# scraped_at           object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   url               283 non-null    object
#  1   name              283 non-null    object
#  2   price             283 non-null    int64
#  3   formatted_price   283 non-null    object
#  4   currency          283 non-null    object
#  5   address           283 non-null    object
#  6   locality          283 non-null    object
#  7   region            283 non-null    object
#  8   postal_code       283 non-null    object
#  9   country           283 non-null    object
#  10  latitude          256 non-null    float64
#  11  longitude         256 non-null    float64
#  12  description       283 non-null    object
#  13  baths             217 non-null    float64
#  14  beds              227 non-null    float64
#  15  sqft              159 non-null    float64
# ...

# %%
data.size
# Out:
# 5943

# %%
data.shape
# Out:
# (283, 21)

# %%
data.head()
# Out:
#                                                  url                     name  \
# 0  https://www.redfin.ca/ab/edmonton/11503-76-Ave...     11503 76 Ave NW #209
# 1  https://www.redfin.ca/on/toronto/30-Roehampton...  30 Roehampton Ave #2608
# 2  https://www.redfin.ca/ab/wood-buffalo/101-McGh...            101 McGhee St
# 3  https://www.redfin.ca/on/waterloo/140-B-Weber-...         140 B Weber St N
# 4  https://www.redfin.ca/ab/rocky-mountain-house/...    5901 71 Ave Unit 304,
#
#     price formatted_price currency                  address  \
# 0  429900       $429,900       USD     11503 76 Ave NW #209
# 1  955000       $955,000       USD  30 Roehampton Ave #2608
# 2  469950       $469,950       USD            101 McGhee St
# 3  699900       $699,900       USD         140 B Weber St N
# 4  213925       $213,925       USD    5901 71 Ave Unit 304,
#
#                locality region postal_code country  ...   longitude  \
# ...

# %%
data.describe()
# Out:
#               price    latitude   longitude       baths        beds  \
# count  2.830000e+02  256.000000  256.000000  217.000000  227.000000
# mean   1.031473e+06   48.770838 -100.553165    2.493088    3.123348
# std    1.574507e+06    3.909100   21.085023    1.422764    1.725071
# min    7.000000e+03   42.017708 -128.517496    1.000000    0.000000
# 25%    2.719500e+05   44.311357 -118.807344    2.000000    2.000000
# 50%    6.499000e+05   49.212257 -112.587022    2.000000    3.000000
# 75%    1.149950e+06   51.470374  -79.517783    3.000000    4.000000
# max    1.770000e+07   58.866691  -52.693754   11.500000   16.000000
#
#                sqft
# count    159.000000
# mean    1831.377358
# std     1963.591751
# min      450.000000
# 25%     1020.000000
# 50%     1244.000000
# 75%     1805.500000
# max    17672.000000

# %%
data.count()
# Out:
# url                 283
# name                283
# price               283
# formatted_price     283
# currency            283
# address             283
# locality            283
# region              283
# postal_code         283
# country             283
# latitude            256
# longitude           256
# description         283
# baths               217
# beds                227
# sqft                159
# property_details    283
# images              242
# listed_by           283
# uniq_id             283
# scraped_at          283
# dtype: int64

# %%
data.min(numeric_only=True)
# Out:
# price        7000.000000
# latitude       42.017708
# longitude    -128.517496
# baths           1.000000
# beds            0.000000
# sqft          450.000000
# dtype: float64

# %%
data.max(numeric_only=True)
# Out:
# price        1.770000e+07
# latitude     5.886669e+01
# longitude   -5.269375e+01
# baths        1.150000e+01
# beds         1.600000e+01
# sqft         1.767200e+04
# dtype: float64

# %%
data.mean(numeric_only=True)
# Out:
# price        1.031473e+06
# latitude     4.877084e+01
# longitude   -1.005532e+02
# baths        2.493088e+00
# beds         3.123348e+00
# sqft         1.831377e+03
# dtype: float64

# %%
data['beds'].value_counts()
# Out:
# beds
# 3.0     74
# 2.0     52
# 4.0     49
# 5.0     14
# 1.0     13
# 0.0     11
# 6.0      8
# 8.0      3
# 7.0      1
# 16.0     1
# 9.0      1
# Name: count, dtype: int64

# %%
data['beds'].unique()
# Out:
# array([ 2.,  3.,  0.,  4., nan,  6.,  5.,  1.,  7.,  8., 16.,  9.])

# %%
data['beds'].nunique()
# Out:
# 11

# %%
data.isnull().sum()
# Out:
# url                   0
# name                  0
# price                 0
# formatted_price       0
# currency              0
# address               0
# locality              0
# region                0
# postal_code           0
# country               0
# latitude             27
# longitude            27
# description           0
# baths                66
# beds                 56
# sqft                124
# property_details      0
# images               41
# listed_by             0
# uniq_id               0
# scraped_at            0
# dtype: int64

# %%
data['sqft'] = data['sqft'].fillna(1831.37)
data['baths'] = data['baths'].fillna(2.49)
data['beds'] = data['beds'].fillna(3.14)
data['latitude'] = data['latitude'].fillna(48.77)
data['longitude'] = data['longitude'].fillna(100.55)

# %%
data.isnull().sum()
# Out:
# url                  0
# name                 0
# price                0
# formatted_price      0
# currency             0
# address              0
# locality             0
# region               0
# postal_code          0
# country              0
# latitude             0
# longitude            0
# description          0
# baths                0
# beds                 0
# sqft                 0
# property_details     0
# images              41
# listed_by            0
# uniq_id              0
# scraped_at           0
# dtype: int64

# %%
data.corr(numeric_only=True)
data.isnull().sum()
# Out:
# url                  0
# name                 0
# price                0
# formatted_price      0
# currency             0
# address              0
# locality             0
# region               0
# postal_code          0
# country              0
# latitude             0
# longitude            0
# description          0
# baths                0
# beds                 0
# sqft                 0
# property_details     0
# images              41
# listed_by            0
# uniq_id              0
# scraped_at           0
# dtype: int64

# %%
sns.relplot(x='baths', y='beds', hue='sqft', data=data)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train = data.drop(['price', 'url', 'name', 'formatted_price', 'currency', 'locality', 'address', 'region', 'postal_code', 'country', 'description', 'property_details', 'images', 'listed_by', 'uniq_id', 'scraped_at'], axis=1)
test = data['price']

# %%
x_train, x_test, y_train, y_test = train_test_split(train, test, test_size = 0.3, random_state=2)

# %%
regr = LinearRegression()

# %%
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = regr.predict(x_test)

# %%
prediction
# Out:
# array([ 601685.98279088, 1623926.62638718,  156512.91816366,
#         308822.2432033 , 1675247.7929638 , 1126737.72549996,
#        2603170.21575938,  610836.7655315 , 1520742.37830896,
#         357595.83941103, 1058622.46889219,  688758.72613593,
#        1242785.55891974,  344428.06578883,  565189.70245039,
#         849818.85110988,  124111.57950688, 1073750.31487097,
#         852580.54071281, 2022893.07588925,  850242.69034817,
#        1641288.77997212, 2898963.61474848,  407612.66885218,
#         841297.36712201,  956853.42329874,  541101.65124767,
#         443501.07662177,  712520.67108319,  148596.3858003 ,
#         604349.26123664, 1810880.00771636, 1424604.00396903,
#         808327.32359228,  923173.0076959 ,  709910.49834204,
#         156512.91816366,  810166.95398686,  799497.6937812 ,
#        1533184.47322201, 1027552.75351809, 1018410.38266384,
#         319461.69470454, 1053450.45331737, 1426122.04167686,
# ...

# %%
regr.score(x_test, y_test)
# Out:
# 0.3926098525907801
